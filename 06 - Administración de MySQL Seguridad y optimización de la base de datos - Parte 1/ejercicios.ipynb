# %% [markdown]
# # Bloque 1

# %% [markdown]
# ## Video 3
#
# Al acceder a Workbench, ¿En cuál pestaña encuentras la opción que te permite recuperar la base de datos?
#
# ---
#
# Administration.
#
#
# ¡Alternativa correcta! Así es, en esta pestaña podrás elegir la opción Data Import/Restore.

# %% [markdown]
# # Bloque 2

# %% [markdown]
# ## Video 1
#
# ¿Cuáles de las siguientes opciones son funciones del DBA (Database Administrator)?
#
# ---
#
# Optimizar las consultas a los informes.
#
#
# ¡Alternativa correcta! Así es, esta función del DBA está relacionada con el mejoramiento del desempeño.
#
#
# Instalar el software.
#
#
# ¡Alternativa correcta! Esta es una de las funciones del DBA.

# %% [markdown]
# ## Video 2
#
# ¿Cuáles parámetros componen la información principal para crear conexiones?
#
#
# ---
#
# Usuario, Servidor, Puerta y Contraseña.
#
#
# ¡Alternativa correcta! Estos son los principales parámetros para crear conexiones.

# %% [markdown]
# ## Video 3
#
# En Windows ¿Cuáles son las maneras de detener y de reiniciar el servicio como presentado en el video?
#
# ---
#
# A través de Servicios y del Símbolo del Sistema.
#
#
# ¡Alternativa correcta! Así es, estas fueron las dos maneras como se detuvo y se reinició el servicio durante el video.

# %% [markdown]
# # Bloque 3

# %% [markdown]
# ## Video 1
#
# Sobre el Tuning de Hardware, ¿Cuáles de las siguientes opciones son verdaderas?
#
# ---
#
# Ver la relación entre RAM y base de datos.
#
#
# ¡Alternativa correcta! Así es, esta opción de análisis para Tuning de Hardware es verdadera.
#
# Usar uma controladora de disco RAID.
#
#
# ¡Alternativa correcta! Esta opción de análisis para Tuning de Hardware es verdadera.

# %% [markdown]
# ## Video 2
#
# ¿Cuál es el comando para ver el valor de una variable global?
#
# ---
#
#
# ```sql
# SHOW GLOBAL STATUS
# ```
#
# ¡Alternativa correcta! Este es el comando para visualizar el valor de una variable global.

# %% [markdown]
# ## Video 3
#
# ¿Dónde aplicamos el mecanismo de almacenamiento?
#
# ---
#
#
# En la tabla.
#
#
# ¡Alternativa correcta! El mecanismo de almacenamiento es una propiedad de la tabla.

# %% [markdown]
# InnoDB
#
# MEMORY
#
#
# ¡Alternativa correcta! El mecanismo de almacenamiento en memoria es el de más rápido acceso.
#
# Alternativa incorreta
# MyISAM

# %% [markdown]
# # Bloque 4

# %% [markdown]
# ## Video 1
#
# Si no modificamos ningún parámetro del ambiente original, ¿Cuál es el mecanismo de almacenamiento por defecto de la versión 8.0 de MySQL?
#
# ---
#
#
# InnoDB
#
#
# ¡Alternativa correcta! Así es, este es el mecanismo de almacenamiento por defecto.

# %% [markdown]
# ## Video 2
#
# ¿Cuál es el comando para la creación de la base de datos?
#
# ---
#
# CREATE
#
#
# ¡Alternativa correcta! Este es el principal comando para la creación de la base de datos.

# %% [markdown]
# ## Video 3
#
# ¿Cuál es la variable de ambiente que determina la localización para la creación de la base de datos?
#
# ---
#
# ``datadir``
#
# ¡Alternativa correcta! Esta es la variable que determina la localización de la base de datos.

# %% [markdown]
# Tengo una base llamada BANCODB, con las siguientes tablas:
#
# - TABLA1
# - TABLA2
# - TABLA3
#
# Queremos ejecutar un backup tan solo de las tablas TABLA1 y TABLA2. ¿Cuál sería el comando para ello?
#
# ---
#
# ```sql
# mysqldump -uroot -p --databases BANCODB --ignore-table BANCODB.TABLA3
# ```
#
# ¡Alternativa correcta! Este es el comando para realizar el backup tan solo de las tablas TABLA1 y TABLA2.

# %% [markdown]
# ¿Cuál es la opción que le permite a Workbench crear un subdirectorio e incluya un archivo de comandos SQL para cada tabla?
#
# ---
#
# Export do Dump Project Folder
#
#
# ¡Alternativa correcta! Así es; aquí creamos un subdirectorio, y en su interior un archivo SQL para recuperar cada tabla.

# %% [markdown]
# Para realizar el backup a través de archivos, seguí los siguientes pasos:
#
# - Detuve el servicio de MySQL.
# - Creé el directorio en el computador.
# - Copié todo el directorio Data en el nuevo directorio creado anteriormente.
# - Reinicié el servicio de MySQL.
#
# Luego de ejecutar estos pasos, fueron realizados cambios en la base, creadas nuevas bases, eliminadas otras, y, cuando recuperamos el backup para deshacer toda la modificación, el procedimiento no fue exitoso.
#
# ¿Dónde está el error?
#
# ---
#
# No se copió el archivo my.ini.
#
#
# ¡Alternativa correcta! El archivo de configuración my.ini debe ser copiado para realizar el backup y sustituido al momento de hacer la recuperación.

# %% [markdown]
# ## Video 4
#
# ¿Cuál es la herramienta que usamos para recuperar una base de datos a través del Símbolo del Sistema?
#
# ---
#
# mysql
#
#
# ¡Alternativa correcta! En realidad, no existe una herramienta específica para recuperar el backup. Tan solo, ejecutamos MySQL y el script con extensión .sql que fue generado por el proceso de backup.
